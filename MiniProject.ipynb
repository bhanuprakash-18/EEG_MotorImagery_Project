# %%
# Miniproject with data from nme over EEG data
import numpy as np
import matplotlib.pyplot as plt
import mne
import os

# %%
path_to_save = './data'

# %%
# dataset = mne.datasets.eegbci.load_data(subjects = np.arange(1,11) , runs = [6], path=path_to_save, force_update=False, update_path=False, base_url='https://physionet.org/files/eegmmidb/1.0.0/', verbose=None)

# %%
files = os.listdir(path_to_save)
print(files)
# Out:
# ['S007', '.DS_Store', 'S009', 'S008', 'S006', 'S001', 'S004', 'S003', 'S002', 'S005', 'S010']

# %%
path_to_datasets = []
raw_datasets = []
for i in range(len(files)):
    if files[i].startswith('S'):
        f = files[i]+"R06.edf"
        path_to_dataset = os.path.join(path_to_save, files[i], f)
        path_to_datasets.append(path_to_dataset)
        raw_dataset= mne.io.read_raw_edf(path_to_dataset, eog=None, misc=None, stim_channel='auto', exclude=(), infer_types=False, include=None, preload=False, units=None, encoding='utf8', exclude_after_unique=False, verbose=None)
        raw_datasets.append(raw_dataset)
# Out:
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S007/S007R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S009/S009R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S008/S008R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S006/S006R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S001/S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S004/S004R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S003/S003R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S002/S002R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S005/S005R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/bhanuprakash/Library/Mobile Documents/com~apple~CloudDocs/MIS/Sem 3/Advanced ML/Mini Project/data/S010/S010R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
path_to_datasets
# Out:
# ['./data/S007/S007R06.edf',
#  './data/S009/S009R06.edf',
#  './data/S008/S008R06.edf',
#  './data/S006/S006R06.edf',
#  './data/S001/S001R06.edf',
#  './data/S004/S004R06.edf',
#  './data/S003/S003R06.edf',
#  './data/S002/S002R06.edf',
#  './data/S005/S005R06.edf',
#  './data/S010/S010R06.edf']

# %%
#raw_dataset
print(raw_datasets[0].info)
#dataset
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 80.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
#  subject_info: <subject_info | his_id: X, sex: 0, last_name: X>
# >

# %%
data_list = []
times_list = []
for i in raw_datasets:
    data, times = i.get_data(return_times=True)
    data_list.append(data)
    times_list.append(times)

# %%
data_list[0]
# Out:
# array([[-2.0e-05,  2.0e-06, -4.8e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 4.0e-06,  4.0e-06, -5.0e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 2.0e-06,  1.0e-06, -5.1e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        ...,
#        [-9.0e-06, -7.3e-05, -2.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        [-2.0e-06, -7.6e-05,  3.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 2.0e-06, -5.4e-05,  1.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00]],
#       shape=(64, 20000))

# %%
data_list[0][1][-100:-1]
# Out:
# array([ 1.2e-05,  2.0e-05, -3.7e-05,  3.9e-05, -1.9e-05, -2.9e-05,
#         2.5e-05, -4.8e-05,  5.0e-06,  1.4e-05, -3.6e-05,  4.5e-05,
#        -7.0e-06, -1.7e-05,  2.9e-05, -5.4e-05,  1.0e-06,  6.0e-06,
#        -4.5e-05,  4.3e-05,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,
#         0.0e+00,  0.0e+00,  0.0e+00])

# %%
times_list[0]
# Out:
# array([0.0000000e+00, 6.2500000e-03, 1.2500000e-02, ..., 1.2498125e+02,
#        1.2498750e+02, 1.2499375e+02], shape=(20000,))

# %%
times_list[0][1]
# Out:
# np.float64(0.00625)

# %%
#raw_dataset.plot()
for i in range(10):
    plt.plot(times_list[i], data_list[i][1:2,:].reshape(-1))
    plt.title(f'Subject {i+1} - Channel 1')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude (µV)')    
    plt.show()

# %%
data.shape
# Out:
# (64, 19680)

# %%
times.shape
# Out:
# (19680,)

# %%
data_list
# Out:
# [array([[-2.0e-05,  2.0e-06, -4.8e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#         [ 4.0e-06,  4.0e-06, -5.0e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#         [ 2.0e-06,  1.0e-06, -5.1e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#         ...,
#         [-9.0e-06, -7.3e-05, -2.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#         [-2.0e-06, -7.6e-05,  3.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#         [ 2.0e-06, -5.4e-05,  1.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00]],
#        shape=(64, 20000)),
#  array([[ 1.05e-04, -2.30e-05, -1.80e-05, ...,  2.43e-04, -2.08e-04,
#           1.00e-04],
#         [-2.30e-05, -7.00e-05, -2.40e-05, ...,  9.80e-05, -7.20e-05,
#           1.20e-04],
#         [ 6.00e-06, -2.60e-05,  1.60e-05, ...,  7.60e-05, -7.40e-05,
#           9.30e-05],
#         ...,
#         [-5.80e-05, -2.00e-06, -4.20e-05, ..., -1.80e-05,  7.60e-05,
#          -1.00e-06],
#         [-6.40e-05, -2.10e-05, -4.40e-05, ..., -2.30e-05,  8.70e-05,
#          -1.00e-06],
#         [-3.00e-05, -2.40e-05, -2.70e-05, ..., -2.10e-05,  9.70e-05,
#          -5.00e-06]], shape=(64, 19680)),
#  array([[-3.3e-05, -3.4e-05, -7.4e-05, ..., -8.1e-05, -4.6e-05, -5.0e-05],
#         [-6.4e-05, -6.9e-05, -8.6e-05, ..., -3.6e-05, -3.2e-05, -4.6e-05],
#         [-3.7e-05, -4.5e-05, -5.3e-05, ..., -3.9e-05, -3.6e-05, -5.5e-05],
#         ...,
#         [-3.0e-05, -3.2e-05, -1.6e-05, ..., -4.6e-05, -5.4e-05, -7.2e-05],
#         [-7.3e-05, -7.8e-05, -6.1e-05, ..., -6.5e-05, -6.9e-05, -8.8e-05],
#         [-2.7e-05, -2.6e-05, -1.6e-05, ..., -4.5e-05, -4.3e-05, -6.1e-05]],
#        shape=(64, 19680)),
#  array([[-3.6e-05, -1.5e-05,  0.0e+00, ...,  2.6e-05, -4.0e-06, -1.7e-05],
#         [-1.3e-05,  1.0e-05,  2.4e-05, ...,  4.0e-05,  2.8e-05,  1.8e-05],
#         [-1.7e-05,  8.0e-06,  2.1e-05, ...,  3.9e-05,  2.6e-05,  1.6e-05],
#         ...,
#         [ 1.3e-05,  1.5e-05,  3.0e-06, ...,  1.2e-05,  2.1e-05,  2.6e-05],
#         [ 1.1e-05,  1.4e-05,  1.0e-06, ...,  1.5e-05,  2.7e-05,  3.9e-05],
#         [ 5.0e-06,  1.0e-05, -5.0e-06, ...,  2.0e-06,  1.2e-05,  1.7e-05]],
#        shape=(64, 19680)),
#  array([[ 7.30e-05,  6.30e-05,  8.20e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         [ 7.30e-05,  6.40e-05,  7.40e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         [ 9.10e-05,  7.80e-05,  8.20e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         ...,
#         [-4.00e-06,  4.00e-06, -3.00e-06, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         [ 5.90e-05,  6.90e-05,  6.50e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         [-9.20e-05, -9.30e-05, -1.02e-04, ...,  0.00e+00,  0.00e+00,
#           0.00e+00]], shape=(64, 20000)),
#  array([[ 3.0e-05,  1.5e-05,  1.0e-06, ..., -2.4e-05, -6.3e-05, -5.8e-05],
#         [ 1.6e-05, -5.0e-06, -2.1e-05, ..., -3.4e-05, -6.9e-05, -6.2e-05],
#         [ 6.0e-06, -2.0e-05, -3.7e-05, ...,  5.1e-05,  1.9e-05,  2.7e-05],
#         ...,
#         [-1.1e-05, -2.0e-05,  3.0e-06, ..., -4.5e-05, -3.8e-05, -3.5e-05],
#         [-2.0e-05, -2.8e-05, -4.0e-06, ..., -4.9e-05, -4.2e-05, -4.0e-05],
#         [-3.0e-05, -4.0e-05, -1.6e-05, ..., -4.1e-05, -3.6e-05, -3.0e-05]],
#        shape=(64, 19680)),
#  array([[-5.90e-05, -8.80e-05, -4.60e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         [-1.01e-04, -1.14e-04, -7.00e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         [-8.70e-05, -9.50e-05, -6.30e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         ...,
#         [-1.60e-05, -6.00e-06,  1.10e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         [-4.00e-06,  6.00e-06,  2.10e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00],
#         [-3.60e-05, -2.60e-05, -1.00e-05, ...,  0.00e+00,  0.00e+00,
#           0.00e+00]], shape=(64, 20000)),
#  array([[-2.0e-06, -1.4e-05,  7.0e-06, ...,  1.5e-05, -5.2e-05, -3.0e-05],
#         [-1.0e-06, -1.0e-05,  5.0e-06, ...,  8.0e-06, -5.4e-05, -1.0e-06],
#         [ 7.0e-06,  0.0e+00,  9.0e-06, ...,  2.0e-05, -1.0e-05,  2.0e-05],
#         ...,
#         [-1.3e-05, -1.0e-06, -2.7e-05, ..., -1.8e-05, -8.0e-06, -1.7e-05],
#         [-1.4e-05, -4.0e-06, -2.0e-05, ..., -5.1e-05, -5.4e-05, -5.3e-05],
#         [-1.4e-05, -3.0e-06, -3.0e-05, ..., -2.1e-05, -8.0e-06, -2.0e-05]],
#        shape=(64, 19680)),
#  array([[-9.1e-05,  6.0e-05, -2.4e-05, ...,  5.0e-06, -4.2e-05,  7.0e-05],
#         [ 2.9e-05, -1.4e-05,  1.6e-05, ..., -6.0e-06,  3.0e-05, -2.2e-05],
#         [ 7.1e-05, -2.7e-05,  4.1e-05, ..., -5.0e-06,  5.2e-05, -5.6e-05],
#         ...,
#         [-1.2e-05,  3.0e-06,  5.0e-05, ...,  6.0e-05, -1.6e-05,  4.1e-05],
#         [-2.4e-05,  6.0e-06,  5.2e-05, ...,  4.6e-05, -4.5e-05,  2.9e-05],
#         [ 5.0e-06, -2.1e-05,  1.4e-05, ...,  5.0e-06, -1.1e-05, -5.0e-06]],
#        shape=(64, 19680)),
#  array([[ 2.90e-05,  1.70e-05,  3.20e-05, ...,  4.30e-05,  6.10e-05,
#           1.11e-04],
#         [ 1.80e-05,  1.20e-05,  1.50e-05, ...,  2.30e-05,  5.20e-05,
#           1.11e-04],
#         [-1.37e-04, -1.33e-04, -1.21e-04, ..., -1.80e-05, -7.00e-06,
#           6.40e-05],
#         ...,
#         [-2.70e-05, -1.40e-05, -8.00e-06, ..., -3.30e-05,  1.80e-05,
#           4.80e-05],
#         [-9.60e-05, -7.80e-05, -7.80e-05, ...,  4.50e-05,  8.60e-05,
#           1.13e-04],
#         [-3.90e-05, -2.00e-05, -2.20e-05, ...,  9.00e-06,  4.10e-05,
#           5.50e-05]], shape=(64, 19680))]

# %%
len(data_list)
# Out:
# 10

# %%
data_list[0]
# Out:
# array([[-2.0e-05,  2.0e-06, -4.8e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 4.0e-06,  4.0e-06, -5.0e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 2.0e-06,  1.0e-06, -5.1e-05, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        ...,
#        [-9.0e-06, -7.3e-05, -2.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        [-2.0e-06, -7.6e-05,  3.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 2.0e-06, -5.4e-05,  1.0e-06, ...,  0.0e+00,  0.0e+00,  0.0e+00]],
#       shape=(64, 20000))

# %%
times_list[0]
# Out:
# array([0.0000000e+00, 6.2500000e-03, 1.2500000e-02, ..., 1.2498125e+02,
#        1.2498750e+02, 1.2499375e+02], shape=(20000,))

# %%
data_list[0][:,1:2].shape
# Out:
# (64, 1)

# %%
data[1:2,:].shape
# Out:
# (1, 19680)

# %%
data[1:2,:].reshape(-1).shape
# Out:
# (19680,)
